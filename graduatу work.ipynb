# %% [markdown]
# # Диплом
#
#
# [Постановка задачи](#Постановка-задачи) <br>
# [Codebook](#Codebook)<br>
# [Требования к работе](#Требования-к-работе)<br>
# [Критерии оценивания](#Критерии-оценивания)<br>
# [Дополнительные материалы](#Дополнительные-материалы) <br>

# %% [markdown]
# ## Постановка задачи
#
# Как и любой бизнес, компания «Мегафон» хочет повысить удовлетворённость своих клиентов качеством услуг. Это важная задача для удержания пользователей — как давних, так и недавно привлечённых. Ведь затраты на маркетинг и продвижение не оправдаются, если клиент уйдёт из-за низкого качества связи. Однако в реальном мире ресурсы всегда ограничены, и в единицу времени технический отдел может решить конечное количество задач. <br>
# Чтобы делать это наиболее эффективно, важно определить, какие технические показатели качества связи сильнее всего влияют на удовлетворённость клиентов, и в первую очередь направить ресурсы на работу с ними. Для этого «Мегафон» провёл опрос своих клиентов, предложив им оценить уровень удовлетворённости качеством связи. По каждому клиенту, прошедшему опрос, были собраны технические показатели. <br>
# Подготовьте исследование для компании «Мегафон» и проанализируйте, как зависит (и зависит ли) оценка, которую ставит клиент в опросе, от технических показателей, которые были собраны. <br><br><br>
#
# **Более подробно о проведённом опросе:**
#
# В ходе опроса компания «Мегафон» предложила своим клиентам оценить уровень удовлетворённости качеством связи по десятибалльной шкале (где 10 — это «отлично», а 1 — «ужасно»). Если клиент оценивал качество связи на 9 или 10 баллов, опрос заканчивался. Если клиент ставил оценку ниже 9, задавался второй вопрос — о причинах неудовлетворённости качеством связи с предоставленными пронумерованными вариантами ответа. Ответ можно было дать в свободном формате или перечислить номера ответов через запятую. Ниже вы можете ознакомиться с инфографикой по структуре опроса.<br>
#
# *Обратите, пожалуйста, внимание, что для работы вам даны реальные данные, что может повлечь необходимость в дополнительной их обработке.*

# %% [markdown]
# ![](https://sun9-32.userapi.com/C6vN5pHQW7hlseIt0AtTN7qNDQbDnHXdt1P2NA/ILntXqa-RrA.jpg)

# %% [markdown]
# ## Codebook
#
# `megafon.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `user_id` — идентификатор абонента;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Q1` — ответ на первый вопрос;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Q2` — ответ на второй вопрос;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Total Traffic(MB)` — объем трафика передачи данных <sup>1 </sup>; <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Downlink Throughput(Kbps)` — средняя скорость «к абоненту» <sup>2 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Uplink Throughput(Kbps)`— средняя скорость «от абонента» <sup>3 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Downlink TCP Retransmission Rate(%)` — частота переотправок пакетов «к абоненту» <sup>4 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Video Streaming Download Throughput(Kbps)` — скорость загрузки потокового видео <sup>5 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Video Streaming xKB Start Delay(ms)` — задержка старта воспроизведения видео <sup>6 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Web Page Download Throughput(Kbps)` — скорость загрузки web-страниц через браузер <sup>7 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Web Average TCP RTT(ms)` — пинг при просмотре web-страниц<sup>8 </sup>.<br>
#
#
# <sup>1 </sup> — Насколько активно абонент использует мобильный интернет.<br>
# <sup>2 </sup> — Считается по всему трафику передачи данных.<br>
# <sup>3 </sup> — Считается по всему трафику передачи данных.<br>
# <sup>4 </sup> — Чем выше, тем хуже. Если в канале возникает ошибка, пакет переотправляется. Снижается полезная скорость.<br>
# <sup>5 </sup> — Чем выше, тем лучше — меньше прерываний и лучше качество картинки.<br>
# <sup>6 </sup> — Сколько времени пройдёт между нажатием на кнопку Play и началом воспроизведения видео. Чем меньше это время, тем быстрее начинается воспроизведение.<br>
# <sup>7 </sup> — Чем выше, тем лучше.<br>
# <sup>8 </sup> — Чем меньше, тем лучше — быстрее загружаются web-страницы.<br>
#
# Первый технический показатель представлен как сумма за период в одну неделю перед участием в опросе. Остальные технические показатели отображают среднее значение по данному признаку за период в одну неделю перед участием в опросе.

# %% [markdown]
# # Требования к работе
#
# Составьте работу из нескольких частей, в каждой из которых формулируется вопрос к данным или статистическая гипотеза о данных, например:
# * На основании данных какое самое вероятное значение величины X? Каков доверительный интервал для неё?
# * Верно ли, что для групп A и B значения величины X статистически достоверно различаются? На сколько?
#
# И далее по результатам анализа дайте развёрнутый ответ на этот вопрос.
#
# Сделайте **минимум три части** в работе, максимальное количество частей не ограничено. Хотя бы одна из них должна быть связана с первым вопросом из опроса «Мегафона» и хотя бы одна — со вторым. Организуйте **каждую** из частей в соответствии со следующей структурой:
#
# 1. **Постановка задачи**
#
#    **Что** Вы хотите проанализировать и **зачем**?
#     <br><br> Опишите предмет анализа с обоснованием его выбора. Почему вы хотите исследовать это предположение? Как ответ на этот вопрос поможет компании «Мегафон» с точки зрения бизнеса?<br><br>
#
# 2. **Блок с разведочным анализом**
#
#    Перед тем, как проверить своё предположение статистическими методами, посмотрите, что в данных имеется соответствующий «сигнал». Сделайте необходимые визуализации и опишите видимые тенденции в данных.<br><br>
#
# 3. **Блок со статистическим тестом**
#
#    Выберите метод для статистической проверки вашего предположения, письменно обоснуйте свой выбор. Проверьте, удовлетворяет ли выборка допущениям (assumptions) выбранного вами теста. Реализуйте тест и на основании результатов сформируйте вывод.<br><br>
#
# 4. **Вывод**
#
#    Обобщите результаты вашего анализа. Проговорите ещё раз ваше изначальное предположение, изложите вывод по результатам статистичекого анализа. Если ваше предположение не подтвердилось, напишите, как вы думаете, почему так получилось.
# <br><br>
#
#
#
# На проверку отправьте два документа:
# 1. Ноутбук с проведённым анализом и кодом решения.
# 2. Презентация результатов, которая будет использована для защиты работы перед комиссией (файл в формате PDF).
# <br><br>
# Рекомендации по структуре презентации можно найти [по ссылке](https://docs.google.com/document/d/1oD3xe_xPKuhOIvjyaaM5KLM4cegycjo2kRIOHs3hoyw/edit?usp=sharing).

# %% [markdown]
# ## Критерии оценивания
#
# **Общие критерии:** <br>
# Каждый шаг анализа должен быть обоснован. Когда вы формулируете вопрос для исследования, обоснуйте, как ответ на него поможет компании «Мегафон» решить поставленную задачу. Если выбираете определённый способ визуализации, обоснуйте, почему такой способ отображения данных лучше всего подходит для данного типа данных. Если выбираете определённый статистический тест, обоснуйте, почему этот тест подходит для проверки вашего предположения. Если вы делаете очистку или обработку данных, обоснуйте, почему такая обработка (конкретный шаг) необходима. <br><br>
#
# ***При отсутствии обоснования хотя бы по одному из шагов работа не проверяется и отправляется на доработку.***
#
# <br>
#
# **Критерии оценки кода:**
# - Корректность реализации той задачи, которая была поставлена.
# - Соблюдение основных стандартов стиля по PEP8 (пробелы, отступы, названия переменных, единый стиль кода).
# - Комментарии или текстовое описание к каждому логическому блоку кода.
#
# **Критерии оценки визуализации:**
# - Каждый график должен иметь заголовок.
# - Оси графиков должны быть подписаны.
# - Наличие легенды, если тип графика это предполагает.
# - Соответствие типа графика тому, что предполагается объяснить этим графиком.
# - Понятность, читаемость графика.
#
# **Критерии оценки статистического анализа:**
# - Соответствие теста поставленной задаче.
# - Удовлетворение выборкой assumptions теста.
# - Корректность математических расчётов при проведении теста.

# %% [markdown]
# ## Дополнительные материалы
#
# Для выполнения этого задания вам не нужно разбираться в телекоммуникациях на уровне технического специалиста. Базового представления о терминах, используемых в Codebook, будет достаточно. Для тех, кто столкнулся с ними впервые, и тех, кто хочет освежить знания, мы подготовили несколько ссылок на полезные материалы для понимания контекста:
# <br>
#
#
# **Что такое пакет данных?**<br>
# https://ru.wikipedia.org/wiki/Пакет_(сетевые_технологии)<br><br>
# **Что такое пинг/RTT?** <br>
# https://ru.wikipedia.org/wiki/Круговая_задержка <br><br>
# **Как работает протокол TCP?**<br>
# https://youtu.be/CKUOb4htnB4<br><br>
# **Что такое ошибка в канале и как происходит переотправка пакета?**<br>
# https://accedian.com/blog/network-packet-loss-retransmissions-and-duplicate-acknowledgements/<br>

# %% [markdown]
# ***

# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import warnings
import scipy.stats as st
from IPython.display import display, HTML, Markdown

warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ***

# %% [markdown]
# # Кастомные функции

# %%
def custom_hist(data, col, title=None, xlab=None, ylab=None, median=False, mean=False, hue=None):
    """Функция отрисовки гистограммы"""

    plt.figure(figsize=(8, 4))
    sns.histplot(data, x=col, kde=False, hue=hue, discrete=True)
    plt.title(title, fontsize=14, pad=15)
    plt.ylabel(ylab)
    plt.xlabel(xlab)
    plt.xticks(np.arange(data[col].min(), data[col].max()+1))

    if mean is True:
        plt.axvline(data[col].mean(), color='m',
                    linestyle='dashed', label='среднее', alpha=0.5)
        plt.legend()

    if median is True:
        plt.axvline(data[col].median(), color='green',
                    linestyle='dashed', label='медиана', alpha=0.7)
        plt.legend()

    return plt.show()

# %%
def q2_map(mark):
    """ Функция по разметке ответов Q2"""
    """mark - строка с ответами на вопрос
       функция возвращает список цифр диапазона ответа без повторов"""

    # Регулярным выражением делим строку на список чисел
    ex = re.findall('\w+', mark)

    # Пробразуем к целому
    ex = list(map(int, ex))

    # Новый список для записи
    new_list = []

    # Итерируемся по списку и проверяем на соответстие условию
    for element in ex:
        if 1 <= element <= 7:
            new_list.append(element)  # Если верный диапазон отметки
        elif element > 10:
            # Если двузначное число, делим по символам и проверяем вхождение в диапазон
            new_list += [int(x) for x in str(element) if 1 <= int(x) <= 7]
        else:
            pass
    # На выходе удаляем дубликаты
    return list(set(new_list))

# %%
def plot_all_group(data, log=False):
    """Функция по визуализации причин по которой клиенты снижали оценку.
    Сначала убирает нейтральные оценки и сравнивает две группы с хорошими оценками и плохими"""
    
    # Отсеиваем оценки
    data = data[(data.Q1 >= 7) | (data.Q1 <= 4)]
    # Делим на две группы
    data['evaluation'] = data['Q1']\
        .apply(lambda x: 'Not satisfied' if x <= 4 else 'Satisfied')
    # Формируем полотно
    fig, axes = plt.subplots(2, 4, figsize=(20, 8), sharey=False)

    fig.suptitle(f'Плотность распределения', y=1., fontsize=14)

    num = 0
     # Заполняем ax
    for i in range(0, 2):
        for j in range(0, 4):
            param = tech_params[num]
            sns.histplot(ax=axes[i][j], data=data[data[param] != 0],
                         x=param, hue='evaluation', stat='density',
                         hue_order=data.evaluation.unique(),
                         kde=True, log_scale=log, legend=False)

            axes[i][j].set_ylabel('Плотность')
            # Вычленяем единицу измерения
            if log == True:
                axes[i][j].set_xlabel('Log: ' + re.findall(r'\((\S+)\)', tech_params[num])[0])
            else:
                axes[i][j].set_xlabel(re.findall(r'\((\S+)\)', tech_params[num])[0])
                
            axes[i][j].set_title(param)
            plt.legend(data.evaluation.unique())
            sns.despine()
            num += 1
    plt.subplots_adjust(wspace=0.25, hspace=.4)
    return plt.show()

# %%
def printmd(string):
    """Функция print в стиле Markdown"""
    
    display(Markdown(string))

# %%
def bootstrap(data_a, data_b, N=5000, size=200, title=None):
    """Функция бутстрэпа, расчет и отрисовка"""
    
    # Реализация бутстрэпа
    mean_samples_a = []
    mean_samples_b = []
    buf = []
    
    for i in range(N):
        sample_a =  data_a.sample(size)
        mean_samples_a.append(np.mean(sample_a))
        sample_b =  data_b.sample(size)
        mean_samples_b.append(np.mean(sample_b))
        buf.append(np.mean(sample_a)-np.mean(sample_b))
        
    # Инициализация полотна
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle(title, y=1.05, fontsize=14)
    
    # Графики распределения по группам А и Б
    sns.histplot(mean_samples_a, alpha=.8, ax=ax[0], kde=True, stat='density')
    sns.histplot(mean_samples_b, color='orange', alpha=.8, ax=ax[0], kde=True, stat='density')
    # Интервалы и медиана
    ax[0].axvline(np.percentile(mean_samples_a, 2.5), linestyle='-', color='r', linewidth=3)
    ax[0].axvline(np.percentile(mean_samples_a, 97.5), linestyle='-', color='r', linewidth=3)
    ax[0].axvline(np.median(mean_samples_a), linestyle='--', color='r', linewidth=3)
    ax[0].axvline(np.percentile(mean_samples_b, 2.5), linestyle='-', color='g', linewidth=3)
    ax[0].axvline(np.percentile(mean_samples_b, 97.5), linestyle='-', color='g', linewidth=3)
    ax[0].axvline(np.median(mean_samples_b), linestyle='--', color='g', linewidth=3)
    ax[0].set_title('Плотность распределения по группам \n с хорошими и плохими оценками', fontsize=14)
    ax[0].set_ylabel('Плотность')
    ax[0].set_xlabel(re.findall(r'\((\S+)\)', title)[0])
    ax[0].legend(['Хорошие','Плохие'])
    
    # График распределения разности по группам А и Б
    sns.histplot(buf, alpha=.8, ax=ax[1], kde=True, stat='density', color='g')
    # Интервалы и медиана
    ax[1].axvline(np.percentile(buf, 2.5), linestyle='-', color='b', linewidth=3)
    ax[1].axvline(np.percentile(buf, 97.5), linestyle='-', color='b', linewidth=3)
    ax[1].axvline(np.median(buf), linestyle='--', color='b', linewidth=3)
    ax[1].set_title('Плотность разницы средних', fontsize=14)
    ax[1].set_ylabel('Плотность')
    ax[1].set_xlabel(re.findall(r'\((\S+)\)', title)[0])
    return plt.show()

# %%
sns.set_theme(style='darkgrid')

# %% [markdown]
# ***

# %% [markdown]
# # Загрузка данных

# %%
# Загрузка данных
df = pd.read_csv('megafon.csv')
df.tail(3)
# Out:
#       user_id  Q1    Q2  Total Traffic(MB)  Downlink Throughput(Kbps)  \
# 3109     3110  10   NaN          187.44936                     590.29
# 3110     3111   6  1, 3          827.74515                    1841.90
# 3111     3112   6   NaN          596.22757                    2196.00
#
#       Uplink Throughput(Kbps)  Downlink TCP Retransmission Rate(%)  \
# 3109                   186.36                                 2.06
# 3110                   373.53                                 1.21
# 3111                   265.87                                 0.41
#
#       Video Streaming Download Throughput(Kbps)  \
# 3109                                    3182.83
# 3110                                    5675.93
# 3111                                    9295.59
#
#       Video Streaming xKB Start Delay(ms)  Web Page Download Throughput(Kbps)  \
# 3109                                 2195                             1094.62
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3112 entries, 0 to 3111
# Data columns (total 11 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   user_id                                    3112 non-null   int64
#  1   Q1                                         3110 non-null   object
#  2   Q2                                         1315 non-null   object
#  3   Total Traffic(MB)                          3112 non-null   float64
#  4   Downlink Throughput(Kbps)                  3112 non-null   float64
#  5   Uplink Throughput(Kbps)                    3112 non-null   float64
#  6   Downlink TCP Retransmission Rate(%)        3112 non-null   float64
#  7   Video Streaming Download Throughput(Kbps)  3112 non-null   float64
#  8   Video Streaming xKB Start Delay(ms)        3112 non-null   int64
#  9   Web Page Download Throughput(Kbps)         3112 non-null   float64
# ...

# %% [markdown]
# В нашей выгрузке по абонентам есть два пропуска среди ответов на первый вопрос **Q1**. Так как мы никак не можем их идентифицировать, то удалим их из датафрейма. Также следует проверить на корректность ответы на 1 вопрос. <br><br>
# Ответы в **Q2** идут через запятую, при выборе нескольких вариантов ответа на второй вопрос. <br>
# Также есть много пропусков. Часть этих пропусков, это ответ на первый вопрос в диапазоне от 9 до 10, так как далее тестирование заканчивается. Но, вероятно, там есть и пропуски при неудовлетворительной оценке. Этот столбец необходимо как следует проработать. <br><br>
# Данные с показателями качества связи без пропусков, типы данных загрузились корректно.

# %% [markdown]
# Так как данные, указывающие на качество связи определяются коррекно, следует проверить качество ответов на вопросы пользователей.

# %%
df.describe(include=object)
# Out:
#           Q1    Q2
# count   3110  1315
# unique    49    51
# top       10     3
# freq     846   190

# %% [markdown]
# Мы видим большое количество уникальных значений при ответе на первый и второй вопрос. <br>
#
# Для `Q1` - 10 уникальных вариантов ответа исходя из условия опроса. Хотя диапазон этих ответов ограничен самим вопросом. <br>
#
# Для `Q2` нет ограничений, так как можно давать ответ в свободной форме. <br>

# %% [markdown]
# ## Пост обработка ответов Q1

# %% [markdown]
# Визуально оценим, качество ответов на 1 вопрос опроса.

# %%
print(df['Q1'].unique())
# Out:
# ['5' '1' '8' '2' '3' '9' '10' '7' '4' '11' '6' '2, 9' '0' '1, 3' '19' '15'
#  nan '1, 6' '***** ** ***'
#  '3 - дер.Ширяево Волоколамского района, 9 - в Москве' '10, 9'
#  'Чем даль ше,тем лучше.Спасибо за ваш труд.Оценка 10 !'
#  'ОЦЕНКА-3/НЕВАЖНО/' 'Отвратительно' 'Я ценой услуг не удовлетворен'
#  'Пока не понял' '3, 9' '5, 6' '0, 1, 5' '5, 7' 'Hi'
#  '4. Тульская область Заокский район. Романовские дачи связи почти нет'
#  'Немагу дать атценку денги незашто снимаеть скоро выклучаю' '10, 50'
#  'Очень  хорошо. Обслуживания  я довольно. Спасибо вам.555' '?' 'Поохое'
#  'Когда в Москве-10 а когда в калужской области в деревне Бели-1' 'Нет'
#  'Да' 'Ужасно'
#  '3 тройка, связь отвратительная, жалко платить за такой тарив'
#  'Чдтчдтччдтччч' '3, 7' '20, 89031081392' '1, 8' 'Без з' '10, 5' '2, 5'
#  'Я в Смол. Области живу сейчас, не пользуюсь телефоном совсем']

# %% [markdown]
# Мы видим много ответов, которые не укладываются в критерии оценки, заданные условием. <br>
# Мы можем пойти дальше двумя путями: <br>
# 1. Оценивать все уникальные записи (например вычлинять регулярными выражениями или проводить морфологический анализ);
# 2. Удалить некорректные ответы.
# <br>
#
# Второй вариант самый простой. Первый же сложный не только в плане техничекой реализации, но и в плане интерпритации полученных оценок. <br>
# Например, как интерпритировать ответ "10, 5"? Это хорошо или плохо. Какой вариант ошибочный? Или взять среднее? <br>
# Или же ответ "Я ценой услуг не удовлетворен". Как охарактеризовать? <br> Оценка не имеет отношения к качесту услуг, а только к стоимости. Значит клиент доволен услугами на 10? Непонятно.
# <br><br>
# Прежде чем выбрать каким путём идти, оценим насколько критичен этот процент ошибки по выборке.

# %%
# Удаляем пропуски в ответах на первый вопрос.
df = df[~df.Q1.isna()]

# Список корректных оценок из теста
mark_list = [str(mark) for mark in np.arange(1, 11)]

# %% [markdown]
# Если ответ на Q1 = 0, заменяем на 1

# %%
df.loc[df['Q1'] == '0', 'Q1'] = '1'

# %% [markdown]
# Найдем процент невалидных значений

# %%
# Процент ошибки
error_percent = 1 - \
    df[df['Q1'].isin(mark_list)]['Q1'].count() / df['Q1'].count()
# Количество ошибочных данных
error_count = df[~df['Q1'].isin(mark_list)]['Q1'].count()

print(f'Процент ошибочных записей Q1 - {error_percent:.2%}')
print(f'Количество ошибочных записей Q1 - {error_count}')
# Out:
# Процент ошибочных записей Q1 - 1.35%
# Количество ошибочных записей Q1 - 42

# %% [markdown]
# Мы получили малый процент брака по ответам на вопрос Q1 - 1.35% от всей выборки. <br>
# В силу незначительности колличества, удаляем их из фрейма.

# %%
df = df[df['Q1'].isin(mark_list)]
df.Q1 = df.Q1.astype('int64')

# %% [markdown]
# ## Пост обработка ответов Q2

# %% [markdown]
# Для понимания влияния тех или иных технических показателей на оценку, рассмотрим, как пользователи отвечали на данный вопрос.

# %%
df.Q2.unique()
# Out:
# array([nan, '4', '3', '2, 3, 4', '4, 5', '1, 3, 4', '1, 3, 4, 5', '1, 3',
#        '3, 4', '1, 2', '3, 5', '1', '7', '1, 4', '1, 2, 3, 4, 5', '2, 3',
#        '1, 2, 3, 4', '2, 3, 4, 5', '3, 4, 5', '1, 2, 5', '1, 5',
#        '1, 2, 4', '6', '1, 4, 5', '1, 2, 3', '2, 5', '2, 4, 5', '1, 2, 7',
#        '5', '2', '1, 2, 3, 4, 5, 6', '0, 1, 7', '4, 7', '1, 4, 7', '0, 3',
#        '1, 3, 4, 5, 7', '3, 7', '1, 3, 4, 7', '3, 4, 5, 7', '2, 4',
#        '5, 6', '1, 2, 3, 5', '1, 3, 5', '1, 2, 34', '1, 2, 4, 5',
#        '0, 05, 2, 27, 7', '1, 3, 7', '3, 4, 7', '1, 2, 3, 4, 7', '10',
#        '0', '1, 2, 3, 7'], dtype=object)

# %% [markdown]
# В целом данные коррекно, заполнены. Но встречаются пропуски и двузначные числа больше 10. Вероятно пропущены запятые между ответами. Обработаем столбец. Уберем не валидные значения и задвоения.

# %%
df.fillna('0', inplace=True)
# Разбиение строки в столбце на список значений(ответов) на Q2
df['Q2'] = df['Q2'].apply(lambda x: q2_map(x))

# Количество претензионных оценок на клиента
df['DisCount'] = df['Q2'].apply(lambda x: len(x))

# %%
df.head(3)
# Out:
#    user_id  Q1   Q2  Total Traffic(MB)  Downlink Throughput(Kbps)  \
# 0        1   5   []          775.48846                     360.13
# 1        2   5  [4]          861.96324                    3023.54
# 2        3   1  [4]          261.11860                     790.96
#
#    Uplink Throughput(Kbps)  Downlink TCP Retransmission Rate(%)  \
# 0                    86.56                                 3.93
# 1                   411.18                                 1.27
# 2                    34.20                                 1.79
#
#    Video Streaming Download Throughput(Kbps)  \
# 0                                    1859.15
# 1                                     667.47
# 2                                    1079.60
#
#    Video Streaming xKB Start Delay(ms)  Web Page Download Throughput(Kbps)  \
# 0                                 2309                             1007.82
# 1                                 2080                              255.36
# ...

# %% [markdown]
# Ответы на Q2 обработаны, убраны не валидные значения и дубликаты.

# %% [markdown]
# ***

# %% [markdown]
# # Индекс удовлетворенности клиентов сервисом - CSAT.

# %% [markdown]
# **Рассчитаем CSAT – Customer Satisfaction Score**

# %% [markdown]
# CSAT – это Индекс удовлетворённости клиента, эта метрика призвана замерять уровень "клиентского счастья". <br>
# Иными словами это некая средняя величина, выражающая степень соответствия реальных услуг и товаров тем, которые клиенты должны были предположительно получить. <br>
# В нашем случае оценка ведется по десятибальной шкале: от "ужасно" к "отлично".
# <br><br>
# Зачем измерять? <br>
# Оценка удовлетворенности требуется для сбора обратной связи клиентов с помощью опросов. Чтобы знать наверняка мнение пользователя, нужно просто спросить, каковы его впечатления от продукта или сервиса.

# %% [markdown]
# ![](https://cdn-www.carrotquest.io/blog/wp-content/uploads/2019/02/ocenka-operatorov-3-3.jpg)

# %% [markdown]
# Какие недостатки у метода CSAT?
#
# * Возможно искажение результатов. Недовольные клиенты склонны в принципе не проходить опросы (исключение — очень недовольные клиенты, которые используют любую возможность, чтобы сообщить о своём опыте). Пользователи, оценка которых колеблется от нейтральной до неудовлетворительной, часто не отвечают на вопросы. Довольные же клиенты охотно соглашаются из соображений благодарности.
#
# * Субъективность и неоднозначность. У разных клиентов разные ожидания. Для кого-то лишняя фраза, сказанная менеджером, может стать пыткой и говорить об ужасном сервисе, а кому-то важны любезности при разговоре.

# %% [markdown]
# **Рассчитаем CSAT по формуле:**

# %% [markdown]
# ![](https://lh6.googleusercontent.com/4sLLhONJV_gIsxLLFcm-EZUp3Y12jktlnv9BaaiOjhqaHLkRIH4-u7l-K0B3xCvRvCzCTVktrumvnYoXsIhC7-R987ma9Id02N9Hb4boogdkZH2PE0u3IGRolEJ4bpNkT7hFugNJ)

# %% [markdown]
# Также ведем градацию оценок:
# - 1-2 балла - ужасно;
# - 3-4 балла - плохо;
# - 5-6 баллов - нейтрально;
# - 7-8 баллов - хорошо;
# - 9-10 баллов - отлично.

# %% [markdown]
# ![](https://s3.amazonaws.com/cdn.freshdesk.com/data/helpdesk/attachments/production/3049804698/original/9AERLDfC5_TpkAxvsE8qH-NDKD-eVRHWmg.png?1577182457)

# %% [markdown]
# На основании полученных оценок Q1 рассмотрим показатели:
#  - Уровень удовлетворенности клиентов предоставляемыми услугами CSAT;
#  - Средняя оценка уровню сервиса.

# %%
evaluation = {1: 'ужасно',
              2: 'ужасно',
              3: 'плохо',
              4: 'плохо',
              5: 'нейтрально',
              6: 'нейтрально',
              7: 'хорошо',
              8: 'хорошо',
              9: 'отлично',
              10: 'отлично'}

df['evaluation'] = df['Q1'].map(evaluation)

# %%
index = df['Q1'].sum() / (df['Q1'].count() * 10)
mean_csat = df['Q1'].sum() / df['Q1'].count()

printmd(f'Процент пользователей, удовлетворенных услугами - {index:.2%}')
printmd(f'Средняя оценка, удовлетворенности услугами - {mean_csat:.2}')
# Out:
# Процент пользователей, удовлетворенных услугами - 60.14%
# Средняя оценка, удовлетворенности услугами - 6.0

# %% [markdown]
# Мы нашли процент клиентов, удовлетворенных качеством сервиса. Но мы имеем 10-ти бальную шкалу и интересно посмотреть как распределились оценки участников опроса при ответе на первый вопрос.

# %%
custom_hist(data=df, col='Q1', title='Распределение оценок Q1',
            xlab='Оценки Q1', ylab='Количество пользователей', median=True, mean=True, hue='evaluation')

# %% [markdown]
# По распределению можно увидеть, что большинство при ответе на вопрос, поставило оценку **10** баллов, в тоже время мы видим большое число людей поставивших оценку "очень плохо". В центре расположились нейтральные оценки, клиенты более предпочтительно ставят крайние варианты ответов (или совсем доволен или совсем не доволен).<br>
# Необходимо более пристально изучить группу людей, ставивших оценки 1 и 2, возможно там скрыта закономерность.<br><br>
# Среднее и медианное значение 6 и 7 соответственно, что говорит о небольшом смещении распределения и достаточно хорошем среднем уровнем оценки качества.
# <br><br>
# Мы получили метрики, которые необходимо улучшать: <br>
# * CSAT - 60,14%
# * Средняя оценка - 6 баллов
# * Медианная оценка - 7 баллов

# %% [markdown]
# **Рассмотрим, какое количество причин выбрали клиенты при ответе на вопрос Q2.**

# %%
custom_hist(data=df, col='DisCount', 
            title='Распределение по количеству \n причин неудовлетворения в вопросе Q2 по всей группе',
            xlab='Количество причин в Q2', ylab='Количество пользователей', median=False, mean=True)

# %% [markdown]
# Можно отметить большое количество нулевых значений, т.е. пользователей, которые не дали ответ на второй вопрос. <br>
# Стоит отметить, что там есть часть клиентов, которые оценили уровень сервиса на 9-10 баллов и после Q1 не участвовали далее в опросе. <br>
# Отсеим эту группу и посмотрим только на тех клиентов, кто оценил качество связи на 8 и менее баллов.

# %%
custom_hist(data=df[~(df['Q1'] >= 9)], col='DisCount',
            title='Распределение по количеству \n причин неудовлетворения в вопросе Q2 в группе \n недовольных качеством услуг',
            xlab='Количество причин в Q2', ylab='Количество пользователей', median=False, mean=True)

# %% [markdown]
# Порядка 650 клиентов не сформулировали ответ на второй вопрос о причинах неудовлетворённости качеством связи с предоставленными пронумерованными вариантами ответа. Ответ можно было дать в свободном формате или перечислить номера ответов через запятую. <br> Но вероятно у них все же есть недовольство услугами. <br>
# Можно сделать допущение, что у клиентов не давших ответ, затруднились с ответом. <br>
# Присвоим этой группе номер ответа на Q2 - 6. <br>

# %%
# Присвоим нулевое значение на Q2, клиентам довольных услугами
df.loc[df['Q1'] >= 9, 'Q2'] = 0

# %%
# Присвоим значение 6 на Q2, клиентам не довольных услугами и не давших ответ на вопрос Q2
df.loc[(df['DisCount'] == 0) & (df['Q1'] <= 8), 'Q2'] = 6
# Изменим количество оценок на Q2 с нуля на 1, клиентам не довольных услугами и не давших ответ на вопрос Q2
df.loc[df['Q2'] == 6, 'DisCount'] = 1

# %%
# Размножим датасет (развернем списки Q2)
df_long = df.explode('Q2').reset_index(drop=True)
df_long.Q2 = df_long.Q2.astype('int64')

# %%
# Разметим датафрейм по вариантам ответа
legend = {0: 'Устраивает качество связи',
          1: 'Недозвоны, обрывы при звонках',
          2: 'Время ожидания гудков при звонке',
          3: 'Плохое качество связи в зданиях',
          4: 'Медленный мобильный интернет',
          5: 'Медленная загрузка видео',
          6: 'Затрудняюсь ответить',
          7: 'Свой вариант'}

df_long['legend'] = df_long['Q2'].map(legend)

# %% [markdown]
# Рассмотрим как распределилась средняя оценка среди тех, кто отвечал на Q2.

# %%
# Расчет среднего балла
df_q2_mean = df_long.groupby(['Q2', 'legend']).agg({'Q1' : 'mean'})
df_q2_mean.rename(columns={'Q1' : 'Средний балл'}, inplace=True)

display(df_q2_mean.round(2).style\
        .background_gradient(cmap='viridis', low=.5, high=0)\
        .set_caption('Средний балл по ответам на Q2')\
        .format("{:}"))
# Out:
# <style  type="text/css" >
# #T_5cbd9f66_9f0b_11eb_a7b9_8019346f79c0row0_col0{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_5cbd9f66_9f0b_11eb_a7b9_8019346f79c0row1_col0{
#             background-color:  #297a8e;
#             color:  #000000;
#         }#T_5cbd9f66_9f0b_11eb_a7b9_8019346f79c0row2_col0{
#             background-color:  #2a788e;
#             color:  #000000;
#         }#T_5cbd9f66_9f0b_11eb_a7b9_8019346f79c0row3_col0{
#             background-color:  #277f8e;
#             color:  #000000;
#         }#T_5cbd9f66_9f0b_11eb_a7b9_8019346f79c0row4_col0,#T_5cbd9f66_9f0b_11eb_a7b9_8019346f79c0row5_col0{
#             background-color:  #297b8e;
#             color:  #000000;
#         }#T_5cbd9f66_9f0b_11eb_a7b9_8019346f79c0row6_col0{
#             background-color:  #277e8e;
#             color:  #000000;
#         }#T_5cbd9f66_9f0b_11eb_a7b9_8019346f79c0row7_col0{
#             background-color:  #31688e;
# ...

# %% [markdown]
# В среднем оценки распределились ровно. Средний балл по каждому варианту Q2 примерно одинаковый 3.6 - 3.9. <br>
# Выделяется вариант ответа "Свой вариант", вероятно в этой категории есть много негативно настроенных клиентов, по каким-то причинам не связанным с технической стороной качества связи.

# %% [markdown]
# Рассмотрим как распределились ответы на второй вопрос, чтобы понять, упоминание каких причин неудовлетворительной связи по мнению пользователей являются для них приоритетным.

# %%
df_bad = df_long[~df_long.Q2.isin([0])]

plt.figure(figsize=(15, 6))
sns.countplot(y='legend', data=df_bad,
              order=df_bad.groupby(['legend']).count().sort_values(by='user_id', ascending=False).index, 
              orient='h')
plt.title('Наиболее часто встречающиеся ответы на Q2', fontsize=14, pad=15)
plt.xlabel('Количество пользователей')
plt.ylabel('')
plt.show()

# %% [markdown]
# Наши ТОП-3 причины заниженных оценок:
#
# * Плохое качество связи в зданиях;
# * Недозвоны, обрывы при звонках;
# * Медленный мобильный интернет.
#
# Эти три категории являются наиболее приоритетными ввиду большого количества клиентов, упомянувших о них. <br>
# Вариант "затрудняюсь ответить" не рассматривается, так как невозможно идентифицировать причину недовольства. <br>
# Эту группу людей предлагается включить в участие в аналогичном опросе по другим критериям сервиса.

# %% [markdown]
# # Влияние технических показателей на удовлетворенность качеством услуг

# %% [markdown]
# Попробуем найти взаимосвязи между качеством предоставления услуги на оценку.

# %% [markdown]
# ## Матрица корреляций

# %%
# Технические параметры
tech_params = df_long.columns[3:11].to_list()
# Корреляция
corr = df_long[['Q1'] + tech_params].corr(method='pearson')\
    .sort_values(by=['Q1'], ascending=False).round(2)

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# При интерпритации будем использовать шкалу Чеддока.

# %% [markdown]
# ![](https://ur-consul.ru/Bibli/Kak-pryedskazatjj-kurs-dollara-Effyektivnyye-myetody-prognozirovaniya-s-ispoljjzovaniyem-Excel-i-EViews-11094.jpg)

# %% [markdown]
# Явной корреляции между значениями оценки качества услуг и параметрами связи не обнаружено. <br>
# Но можно отметить корреляцию "Умеренную" и "Заметную" между параметрами:
# * Video Streaming Download Throughput(Kbps);
# * Video Streaming xKB Start Delay(ms);
# * Web Page Download Throughput(Kbps). <br>
#
# Необходимо проконсультироваться с техническими специалистами. Есть вероятность, что если улучшить качество какого-то одного узла, это повлияет сразу на несколько параметров сети.

# %% [markdown]
# ## Зависимость оценки от технических параметров связи по медианным цифрам

# %% [markdown]
# Рассмотрим медианные значения параметров взависимости от характеристики оценки.

# %%
# Рассчет медианных значений
df_grouped = df.groupby('evaluation').agg({'Total Traffic(MB)' : 'median', 
                                     'Downlink Throughput(Kbps)' : 'median',
                                     'Uplink Throughput(Kbps)' : 'median',
                                     'Downlink TCP Retransmission Rate(%)' : 'median',
                                     'Video Streaming Download Throughput(Kbps)' : 'median',
                                     'Video Streaming xKB Start Delay(ms)' : 'median',
                                     'Web Average TCP RTT(ms)' : 'median',
                                     'Web Page Download Throughput(Kbps)' : 'median'}).round(2).reset_index()
# Для сортировки характеристик
df_grouped['order'] = df_grouped['evaluation'].map({'ужасно' : 0,
                                                    'плохо' : 1,
                                                    'нейтрально' : 2,
                                                    'хорошо' : 3,
                                                    'отлично' : 4,})

df_grouped.sort_values(by='order', inplace=True)
df_grouped.drop(columns=['order'], inplace=True)
df_grouped = df_grouped.rename(columns={'evaluation' : 'Характеристика'}).reset_index(drop=True)

# %%
# Отображение таблицы
display(df_grouped.set_index('Характеристика').style\
        .background_gradient(cmap='viridis', low=.5, high=0)\
        .set_caption('Медианные значения параметров')\
        .format("{:}"))
# Out:
# <style  type="text/css" >
# #T_5df1585c_9f0b_11eb_becc_8019346f79c0row0_col0,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row0_col1,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row0_col2,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row0_col7,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row1_col4,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row4_col0,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row4_col3,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row4_col5,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row4_col6{
#             background-color:  #31688e;
#             color:  #f1f1f1;
#         }#T_5df1585c_9f0b_11eb_becc_8019346f79c0row0_col3,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row0_col6,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row1_col5,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row2_col0,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row2_col2,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row4_col1,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row4_col4,#T_5df1585c_9f0b_11eb_becc_8019346f79c0row4_col7{
#             background-color:  #fde725;
# ...

# %%
# Разворачиваем датафрейм по характеристикам
df_param = df.melt(id_vars=['Q1', 'evaluation'], value_vars=tech_params, var_name='Параметр', value_name='Значение')\
  .sort_values(by='Q1', ascending=True)\
  .rename(columns={'evaluation' : 'Характеристика'})

# %%
# Визуализация медианных значений по признакам/характеристикам
fig, axes = plt.subplots(2, 4, figsize=(20, 8), sharex=True)
num = 0
for i in range(0, 2):
    for j in range(0, 4):
        sns.lineplot(y='Значение', x='Характеристика',
                     data=df_param[df_param['Параметр'] == tech_params[num]],
                     err_style="band", estimator=np.median, ax=axes[i][j])

        axes[i][j].set_title(tech_params[num])
        axes[i][j].tick_params(axis='x', rotation=45)
        axes[i][j].set_ylabel('Медиана ' + re.findall(r'\((\S+)\)', tech_params[num])[0])
        sns.despine()
        num += 1
plt.show()

# %% [markdown]
# * `Total Traffic(MB)` — объем трафика передачи данных (сумма за период в одну неделю перед участием в опросе). Можно обратить внимание, что поставившие средние оценки, более активно используют мобильный интернет; <br><br>
# * `Downlink Throughput(Kbps)` — средняя скорость «к абоненту». Здесь видно, что медианное значение растет и вместе с ней улучшается оценка;<br><br>
# * `Uplink Throughput(Kbps)`— средняя скорость «от абонента». Здесь также можно отметить увеличение оценки с увеличением скорости отдачи;<br><br>
# * `Downlink TCP Retransmission Rate(%)` — частота переотправок пакетов «к абоненту». У абонентов с лучшими оценками, меньше ошибок со связью; <br><br>
# * `Video Streaming Download Throughput(Kbps)` — скорость загрузки потокового видео. С ростом скорости загрузки, растет и оценка за сервис; <br><br>
# * `Video Streaming xKB Start Delay(ms)` — задержка старта воспроизведения видео. Чем меньшне по времени загрузка видео, тем более охотно ставят высокий бал клиенты; <br><br>
# * `Web Page Download Throughput(Kbps)` — скорость загрузки web-страниц через браузер. С ростом скорости загрузки, растет и оценка за сервис; <br><br>
# * `Web Average TCP RTT(ms)` — пинг при просмотре web-страниц. Чем меньше, тем лучше — быстрее загружаются web-страницы bи тем более высокие оценки ставят клиенты.<br>

# %% [markdown]
# ## Плотность распределения технических параметров связи

# %% [markdown]
# Рассмотрим плотность распределения по двум группам: <br>
# 1. Группа довольных сервисом. Оценка на Q1 больше 6.
# 2. Группа недовольных сервисом. Оценка на Q1 меньше 5.
# <br>

# %% [markdown]
# Ранее мы уже выявили 3 основные причины заниженных оценок. <br>
# * Плохое качество связи в зданиях - Q2 - ответ 3;
# * Недозвоны, обрывы при звонках - Q2 - ответ 1;
# * Медленный мобильный интернет - Q2 - ответ 4.

# %%
plot_all_group(data=df, log=False)

# %% [markdown]
# Видно, что плотность распределения у двух групп несколько различается, также можно отметить длинные хвосты.
# Визуально оценим теже данные на логарифмированной шкале.

# %% [markdown]
# **Логарифмированная шкала**

# %%
plot_all_group(data=df, log=True)

# %% [markdown]
# Значительная часть негативных оценок заключается в проблех с использованием интернета. Сравнивать будем две группы. Группы поставившие негативные оценки и поставившие высокие оценки качеству связи. Сравнивать будем по характеристикам интернет-соединения. В качестве нулевых гипотез примем статистическое равенство средних у различных групп.

# %% [markdown]
# Выделем две группы которые будем сравнивать:
# * Группа довольных сервисом. Оценка на Q1 больше 6.
# * Группа недовольных сервисом. Оценка на Q1 меньше 5.

# %% [markdown]
# Гипотезы:
# 1. Cредняя скорость «к абоненту» (Downlink Throughput(Kbps)) в двух группах не отличается;
# 2. Cкорость загрузки потокового видео (Video Streaming Download Throughput(Kbps)) в двух группах не отличается;
# 3. Объем трафика передачи данных (Total Traffic(MB)) в двух группах не отличается.

# %% [markdown]
# Во всех случаях будем применять бутстрэп средних, из-за несбалансированности выборок и не достаточного количества наблюдений.

# %% [markdown]
# # Проверка гипотез

# %% [markdown]
# ## Cредняя скорость «к абоненту» (Downlink Throughput(Kbps)) в двух группах не отличается

# %% [markdown]
# ${H_{0}: DT_{bad}=DT_{perfect}}$

# %% [markdown]
# Принимается статистическая гипотеза об отсутствии статистической разницы в двух группах по характеристике Downlink Throughput

# %%
bootstrap(data_a=df[df['Q1'] >= 7]['Downlink Throughput(Kbps)'],
          data_b=df[df['Q1'] <= 4]['Downlink Throughput(Kbps)'],
          N=5000, size=300, title='Downlink Throughput(Kbps)')

# %% [markdown]
# Доверительные интервалы пересекаются, но не накладываются. Медианные значения далеки друг от друга. Разница среднего не проходит через ноль. Нулевую гипотезу равенства отвергаем.

# %% [markdown]
# ## Cкорость загрузки потокового видео (Video Streaming Download Throughput(Kbps)) в двух группах не отличается

# %% [markdown]
# ${H_{0}: VSDT_{bad}=VSDT_{perfect}}$

# %% [markdown]
# Принимается статистическая гипотеза об отсутствии статистической разницы в двух группах по характеристике Video Streaming Download Throughput

# %%
bootstrap(data_a=df[df['Q1'] >= 7]['Video Streaming Download Throughput(Kbps)'],
          data_b=df[df['Q1'] <= 4]['Video Streaming Download Throughput(Kbps)'],
          N=5000, size=300, title='Video Streaming Download Throughput(Kbps)')

# %% [markdown]
# Доверительные интервалы не пересекаются. Нулевую гипотезу отвергаем.

# %% [markdown]
# ## Объем трафика передачи данных (Total Traffic(MB)) в двух группах не отличается

# %% [markdown]
# ${H_{0}: TT_{bad}=TT_{perfect}}$

# %% [markdown]
# Принимается статистическая гипотеза об отсутствии статистической разницы в двух группах по характеристике Total Traffic

# %%
bootstrap(data_a=df[df['Q1'] >= 7]['Total Traffic(MB)'],
          data_b=df[df['Q1'] <= 4]['Total Traffic(MB)'],
          N=5000, size=300, title='Total Traffic(MB)')

# %% [markdown]
# Выборки накладываются друг на друга полностью, разность средних близка к нулю. Нулевую гипотезу равенства принимаем.

# %% [markdown]
# Можно заключить, что для того чтобы повысить удовлетворённость своих клиентов качеством услуг, для удержания пользователей, для повышения уровня оценки пользователями необходимо улучшать качество мобильного интернета и улучшения качества связи.<br>
# Необходимо повышать **среднюю скорость «к абоненту»** и **скорость загрузки потокового видео**. <br>
# Необходимо в первую очередь направить ресурсы на работу с ними.
